# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs

# %%
'''X,y=make_blobs(n_samples=40,centers=2,random_state=2)
clf=svm.SVC(kernel="linear",C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=30)
plt.show()
#to plot the dicision data
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()
xx=np.linspace(xlim[0],xlim[1],30)
yy=np.linspace(ylim[0],ylim[1],30)
YY,XX=np.meshgrid(yy,xx)
xy=np.vstack([XX.ravel(),YY.ravel()]).T
Z=clf.decision_function(xy).reshape(XX.shape)
#plot dicision boundary and margin
ax.contour(XX,YY,Z,color='k',level=[-1,0,1],alpha=0.5,linestyle=["--","-","--"])
#plot SVM
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1],s=100)
plt.show()
           

'''
# Out:
# 'X,y=make_blobs(n_samples=40,centers=2,random_state=2)\nclf=svm.SVC(kernel="linear",C=1000)\nclf.fit(X,y)\nplt.scatter(X[:,0],X[:,1],c=y,s=30)\nplt.show()\n#to plot the dicision data\nax=plt.gca()\nxlim=ax.get_xlim()\nylim=ax.get_ylim()\nxx=np.linspace(xlim[0],xlim[1],30)\nyy=np.linspace(ylim[0],ylim[1],30)\nYY,XX=np.meshgrid(yy,xx)\nxy=np.vstack([XX.ravel(),YY.ravel()]).T\nZ=clf.decision_function(xy).reshape(XX.shape)\n#plot dicision boundary and margin\nax.contour(XX,YY,Z,color=\'k\',level=[-1,0,1],alpha=0.5,linestyle=["--","-","--"])\n#plot SVM\nax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1],s=100)\nplt.show()\n           \n\n'

# %%
X,y=make_blobs(n_samples=40,centers=2,random_state=20)
clf=svm.SVC(kernel="linear",C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=30)
plt.show()

# %%
newData=[[2,4],[6,4]]
clf.predict(newData)
# Out:
# array([0, 1])

# %%
clf=svm.SVC(kernel="linear",C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=30)
#to plot the dicision data
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()
xx=np.linspace(xlim[0],xlim[1],30)
print(xx)
yy=np.linspace(ylim[0],ylim[1],30)
YY,XX=np.meshgrid(yy,xx)
xy=np.vstack([XX.ravel(),YY.ravel()]).T
Z=clf.decision_function(xy).reshape(XX.shape)
#plot dicision boundary and margin
ax.contour(XX,YY,Z,colors='k',levels=[-1,0,1],alpha=1,linestyles=["--","-","--"])
#plot SVM
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1],s=100,facecolors=None)
plt.show()
# Out:
# [ 0.01100503  0.36915618  0.72730732  1.08545847  1.44360961  1.80176076
#   2.15991191  2.51806305  2.8762142   3.23436534  3.59251649  3.95066763
#   4.30881878  4.66696993  5.02512107  5.38327222  5.74142336  6.09957451
#   6.45772565  6.8158768   7.17402794  7.53217909  7.89033024  8.24848138
#   8.60663253  8.96478367  9.32293482  9.68108596 10.03923711 10.39738826]
