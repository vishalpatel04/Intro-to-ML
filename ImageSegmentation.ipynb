# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.cluster import KMeans

# %%
image=mpl.image.imread("civil.jpg")
plt.imshow(image)

# %%
image.shape
# Out:
# (3024, 4032, 3)

# %%
X=image.reshape(-1,3)

# %%
X
# Out:
# array([[174, 174, 164],
#        [172, 172, 162],
#        [172, 172, 162],
#        ...,
#        [ 90, 100, 110],
#        [ 98, 107, 116],
#        [ 78,  87,  96]], dtype=uint8)

# %%
kmean=KMeans(n_clusters=50,n_init=10)
kmean.fit(X)
# Out:
# KMeans(n_clusters=50, n_init=10)

# %%
segmented_img=kmean.cluster_centers_[kmean.labels_]
segmented_img=segmented_img.reshape(image.shape)

# %%
plt.imshow(segmented_img/255)
